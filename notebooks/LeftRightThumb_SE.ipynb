# %%
import numpy as np
import dataIO
import matplotlib.pyplot as plt
from sklearn import svm, preprocessing, cross_validation
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import confusion_matrix
# %matplotlib inline

left, right, left_test, right_test = dataIO.read_twothumb_se(10)

X = np.concatenate((left, right))
y = np.array([0 for x in range(104)]+ [1 for x in range(104)])
test = np.concatenate((left_test, right_test))
y_test = np.array([0 for x in range(52)]+ [1 for x in range(52)])

scaler = preprocessing.StandardScaler().fit(X)  
X_scaled = scaler.transform(X)
test_scaled = scaler.transform(test)

tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-2, 1e-3, 1e-4], # more parameters?
                     'C': [0.001, 0.01, 0.1 ,1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1 ,1, 10, 100, 1000]}]


clf = GridSearchCV(svm.SVC(C=1, cache_size=500), tuned_parameters, cv=10) # scoring function?
clf.fit(X_scaled, y)

print("Best parameters set found on training set:")
print
print clf.best_estimator_
print
print "Grid scores on training set:"
print
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (+/-%0.03f) for %r"
          % (mean_score, scores.std() / 2, params))

y_true, y_pred = y_test, clf.predict(test_scaled)
cm = confusion_matrix(y_true, y_pred)
print
print "Confusion matrix:"
print
print(cm)
print
      
print "Confusion matrix in colour:"
print 
plt.matshow(cm)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('True label')
plt.xlabel('Predicted label')

for i, cas in enumerate(cm):
    for j, c in enumerate(cas):
        if c>0:
            plt.text(j-.2, i+.2, c, fontsize=20)
            
plt.show()
# Out:
# Session used for testing: 2
#
# Best parameters set found on training set:
# SVC(C=10, cache_size=500, class_weight=None, coef0=0.0, degree=3, gamma=0.01,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
#
# Grid scores on training set:
#
# 0.750 (+/-0.043) for {'kernel': 'rbf', 'C': 0.001, 'gamma': 0.01}
# 0.736 (+/-0.059) for {'kernel': 'rbf', 'C': 0.001, 'gamma': 0.001}
# 0.721 (+/-0.063) for {'kernel': 'rbf', 'C': 0.001, 'gamma': 0.0001}
# 0.750 (+/-0.043) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.01}
# 0.736 (+/-0.059) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.001}
# 0.721 (+/-0.063) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.0001}
# 0.731 (+/-0.052) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.01}
# 0.736 (+/-0.059) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}
# 0.721 (+/-0.063) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.0001}
# 0.779 (+/-0.044) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.01}
# 0.736 (+/-0.056) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.721 (+/-0.063) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.851 (+/-0.027) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.01}
# 0.784 (+/-0.044) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.740 (+/-0.051) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.851 (+/-0.037) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.01}
# 0.846 (+/-0.025) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.793 (+/-0.042) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.827 (+/-0.049) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.01}
# 0.841 (+/-0.038) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.841 (+/-0.025) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.750 (+/-0.064) for {'kernel': 'linear', 'C': 0.001}
# 0.798 (+/-0.040) for {'kernel': 'linear', 'C': 0.01}
# 0.837 (+/-0.028) for {'kernel': 'linear', 'C': 0.1}
# 0.837 (+/-0.033) for {'kernel': 'linear', 'C': 1}
# 0.822 (+/-0.037) for {'kernel': 'linear', 'C': 10}
# 0.837 (+/-0.040) for {'kernel': 'linear', 'C': 100}
# 0.827 (+/-0.028) for {'kernel': 'linear', 'C': 1000}
#
# Confusion matrix:
#
# [[52  0]
#  [31 21]]
#
# Confusion matrix in colour:
