# %%
import numpy as np
import matplotlib.pyplot as plt
import dataIO
from sklearn import svm, preprocessing, cross_validation
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import confusion_matrix
# %matplotlib inline


twohand = dataIO.read_file(3, "two_hand")
lefthand = dataIO.read_file(3, "left_hand")
righthand = dataIO.read_file(3, "right_hand")
indexfinger = dataIO.read_file(3, "index_finger")

X = np.concatenate((lefthand, righthand, indexfinger, twohand))
y = np.array([0 for x in range(156)]+ [1 for x in range(156)]+
             [2 for x in range(156)]+[3 for x in range(312)])

scaler = preprocessing.StandardScaler().fit(X)  
X_scaled = scaler.transform(X)

# random_state = seed for random generator
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X_scaled, y, test_size=0.3)

tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4], # more parameters?
                     'C': [0.001, 0.01, 0.1 ,1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1 ,1, 10, 100, 1000]}]


clf = GridSearchCV(svm.SVC(C=1), tuned_parameters, cv=10) # scoring function?
clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print
print clf.best_estimator_
print
print "Grid scores on development set:"
print
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (+/-%0.03f) for %r"
          % (mean_score, scores.std() / 2, params))

y_true, y_pred = y_test, clf.predict(X_test)
cm = confusion_matrix(y_true, y_pred)
print
print "Confusion matrix:"
print
print(cm)
print
      
print "Confusion matrix in colour:"
print 
plt.matshow(cm)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('True label')
plt.xlabel('Predicted label')

for i, cas in enumerate(cm):
    for j, c in enumerate(cas):
        if c>0:
            plt.text(j-.2, i+.2, c, fontsize=20)
            
plt.show()
# Out:
# Best parameters set found on development set:
#
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.001, kernel='rbf', max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)
#
# Grid scores on development set:
#
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 0.001, 'gamma': 0.001}
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 0.001, 'gamma': 0.0001}
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.001}
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.0001}
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.0001}
# 0.921 (+/-0.014) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.392 (+/-0.003) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.987 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.923 (+/-0.018) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.996 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.985 (+/-0.007) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.998 (+/-0.003) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.996 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
# 0.874 (+/-0.026) for {'kernel': 'linear', 'C': 0.001}
# 0.943 (+/-0.019) for {'kernel': 'linear', 'C': 0.01}
# 0.996 (+/-0.004) for {'kernel': 'linear', 'C': 0.1}
# 0.998 (+/-0.003) for {'kernel': 'linear', 'C': 1}
# 0.998 (+/-0.003) for {'kernel': 'linear', 'C': 10}
# 0.998 (+/-0.003) for {'kernel': 'linear', 'C': 100}
# 0.998 (+/-0.003) for {'kernel': 'linear', 'C': 1000}
#
# Confusion matrix:
#
# [[45  1  0  0]
#  [ 0 50  0  0]
#  [ 0  2 38  0]
#  [ 0  0  0 98]]
#
# Confusion matrix in colour:
