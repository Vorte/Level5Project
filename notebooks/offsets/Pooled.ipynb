# %%
import numpy as np
import ast, random, dataIO, common_functions
from sklearn import cross_validation, linear_model
reload(common_functions)
reload(dataIO)

# TODO use Touch class
def get_touch_locations(userid):
    data = {}
    filenos = ["2", "6", "9"]
    
    for fileno in filenos:
        filename = "/home/dimitar/Desktop/Python/experiment/results/"+str(userid)+"_"+fileno+"up.txt"
        with open(filename, "r") as f:
            lines = f.read().splitlines()
            lines = map(lambda x: x.split('\t'), lines[1:])
            map(lambda x: data.setdefault(x[1],[]).append(ast.literal_eval(x[3])), lines)
        
    return data

def run(userId):
    
    locations = get_touch_locations(userId) 
    centers = dataIO.get_key_centers()
    filtered = dataIO.filter_touches(locations)
    
    points = []
    targets_x = []
    targets_y = []
    keys = filtered.keys()
    touch_centers = []
            
    for key in keys:
        touches = filtered[key]
        center = centers[key]
        
        for touch in touches:
            touch_centers.append(center)
            points.append(list(touch))
            #points.append(list(touch)+[touch[0]**2, touch[1]**2])
            targets_x.append(center[0]-touch[0])
            targets_y.append(center[1]-touch[1])       
            
    touch_centers = np.array(touch_centers)
    points = np.array(points)
    
    targets_x = np.array(targets_x)
    targets_y = np.array(targets_y)
    
    points_unz = np.array(map(lambda x: list(x) , zip(*points))) 
    centers_unz = np.array(map(lambda x: list(x) , zip(*touch_centers)))
    
    print("Mean squared error on x before regression: %.2f"
               % np.mean((points_unz[0] - centers_unz[0]) ** 2))
    
    print("Mean squared error on y before regression: %.2f"
               % np.mean((points_unz[1] - centers_unz[1]) ** 2))
    
    mse_x, mse_y, within_before, within_after = common_functions.perform_CV(points, targets_x, 
                                                                            targets_y, touch_centers)
    
#     with open("pooled.txt", "a") as myfile:
#         myfile.write(str(userId)+'\t'+ str(within_before[1])
#                      +'\t'+str(within_after[1])+'\n')
    
    print
    print "####################"
    print 
    print("Mean MSE on x: %.2f" %np.mean(np.array(mse_x)))
    print("Mean MSE on y: %.2f" %np.mean(np.array(mse_y)))
    
    
run(10)
# Out:
# Filtered 2 points.
#
# Mean squared error on x before regression: 326.27
# Mean squared error on y before regression: 143.82
#
# ##### Fold 1 #####
#
# MSE on x: 60.83
# MSE on y: 106.82
#
# ##### Fold 2 #####
#
# MSE on x: 43.41
# MSE on y: 112.60
#
# ##### Fold 3 #####
#
# MSE on x: 90.82
# MSE on y: 104.50
#
# ##### Fold 4 #####
#
# MSE on x: 67.86
# MSE on y: 66.64
#
# ##### Fold 5 #####
#
# MSE on x: 89.69
# MSE on y: 77.90
#
# ##### Fold 6 #####
#
# MSE on x: 116.85
# MSE on y: 315.94
#
# ##### Fold 7 #####
#
# MSE on x: 58.62
# MSE on y: 107.78
# ##### Fold 8 #####
#
# MSE on x: 50.90
# MSE on y: 116.92
#
# ##### Fold 9 #####
#
# MSE on x: 52.29
# MSE on y: 64.22
#
# ##### Fold 10 #####
#
# MSE on x: 79.44
# MSE on y: 97.68
#
# ####################
#
# Mean MSE on x: 71.07
# Mean MSE on y: 117.10

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

nx, ny = (10, 20)
y = np.linspace(10, 470, ny)
x = np.linspace(546, 790, nx)
xv, yv = np.meshgrid(x, y)
xy = np.reshape(np.dstack((xv, yv)), (nx*ny, 2))
xy_unz = zip(*xy)

fig = plt.figure(figsize=(10, 7))

regr_x = linear_model.LinearRegression()
regr_y = linear_model.LinearRegression()
regr_x.fit(points, targets_x)
regr_y.fit(points, targets_y)

pred_x = regr_x.predict(xy)
pred_y = regr_y.predict(xy)

im = plt.imread("../../keyboard.png")
implot = plt.imshow(im, extent=[480, 0, 854, 526])

q = plt.quiver(xy_unz[1], xy_unz[0], pred_y, pred_x, color='red', width = 0.005, angles='xy')

plt.show()

# %%
fig = plt.figure(figsize=(10, 7))

plt.errorbar(range(1,11), within_after, marker="o")
plt.errorbar(range(1,11), within_before, linestyle="--", marker="o")

plt.show()

# %%
for i in range(3, 18):
    run(i)
