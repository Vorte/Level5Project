# %%
import numpy as np
#1

noregr = np.array([0.71113989637305697, 0.5, 0.69210866752910738, 0.72691807542262676, 0.78599221789883267, 0.55141388174807193, 0.58473479948253559, 0.58517555266579979, 0.8784313725490196, 0.54252577319587625, 0.55701179554390567, 0.64819587628865982, 0.69062901155327339, 0.51554404145077726, 0.5])
predSVM = np.array([0.8134698634698635, 0.75209790209790206, 0.76336996336996343, 0.83099794941900207, 0.87027972027972011, 0.86501831501831494, 0.79560439560439566, 0.86739576213260405, 0.9163533834586467, 0.83623043623043625, 0.76418318523581685, 0.85820845820845815, 0.92044622044622049, 0.75644355644355632, 0.77134532134532141])
predGP = np.array([0.81733266733266741, 0.75704295704295699, 0.75541125541125553, 0.82701640464798365, 0.87031302031302027, 0.86751581751581752, 0.79813519813519818, 0.8609022556390975, 0.92159945317840053, 0.84285714285714275, 0.76531100478468894, 0.85812520812520821, 0.9242424242424242, 0.75516150516150515, 0.78687978687978677])
averGP = np.array([0.83018648018648022, 0.76613386613386614, 0.76325341325341323, 0.82178742310321273, 0.8793539793539793, 0.87261072261072281, 0.7994505494505495, 0.8583048530416949, 0.91628503075871515, 0.84933399933399922, 0.77846889952153109, 0.85424575424575422, 0.93071928071928078, 0.73315018315018321, 0.75832500832500838])


noregr_mse = np.array([293.45595854922283, 457.187338501292, 324.36028460543338, 279.50910273081922, 228.88132295719845, 433.52056555269917, 422.71216041397156, 398.3855656697009, 198.47647058823532, 433.34536082474227, 477.60091743119267, 330.32474226804129, 316.76187419768934, 452.62694300518137, 485.13565891472871])
predSVM_mse = np.array([230.72380388234484, 255.86962908519087, 264.66743122706509, 227.06061507466831, 179.91945519126631, 190.9158690914949, 238.70968645901971, 188.44862015815349, 157.08500483897711, 207.88474189445452, 289.28827304696364, 206.59232693862276, 141.33916182385846, 287.71347652735881, 267.08753460513145])
predGP_mse = np.array([230.06667109352844, 255.46207237562487, 265.77126871550024, 227.84265942628571, 181.10021812243207, 188.31505745737519, 238.32296873503972, 188.39541765431076, 153.78393997576859, 205.26723861592401, 286.9744079552903, 208.06435570305916, 138.51696536669567, 284.1733722518195, 259.51892422868912])
averGP_mse = np.array([228.22453922673142, 254.61304867204262, 264.28386422035658, 223.75687819825123, 176.81020433118039, 188.59385422732629, 233.58001354657785, 187.77974411170945, 156.65786406029432, 204.99560574869543, 279.83701150964521, 204.08081921072881, 138.77009461793401, 287.61181929721863, 274.7269302034411])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(12, 7))

plt.errorbar(range(3,18), noregr,  fmt='o', color ='g', label='No Model')
plt.errorbar(range(3,18), predSVM, fmt='o', color = 'y', label='PredictSVM')
plt.errorbar(range(3,18), predGP, fmt='o', color='cyan', label='PredictGP')
plt.errorbar(range(3,18), averGP, fmt='o', color='magenta', label='AverageGP')

plt.legend(loc='best')
plt.xlabel('user ID')
plt.ylabel('% of touches within 2mm button')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=2)
#plt.savefig('/home/dimitar/Desktop/Latex/L5Project/mpaper/img/overall_post.png', bbox_inches='tight', dpi=400)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(12, 7))
index = np.arange(2.6, 17, 1)
bar_width = 0.2

plt.bar(index, averGP, color='magenta', label='AverageGP', width = bar_width)
plt.bar(index+bar_width, predGP, color='cyan', label='PredictGP', width = bar_width)
plt.bar(index+2*bar_width, predSVM, color = 'y', label='PredictSVM', width = bar_width)
plt.bar(index+3*bar_width, noregr,  color ='g', label='No Model', width = bar_width)

plt.ylim((0.49,0.94))
plt.xticks(())
plt.legend(loc='best')
plt.xlabel('user ID')
plt.ylabel('% of touches within 2mm button')
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.12), ncol=2)
#plt.savefig('/home/dimitar/Desktop/Latex/L5Project/mpaper/img/overall_post.png', bbox_inches='tight', dpi=400)
plt.show()

# %%
np.arange(2.6, 18.6, 1)
print np.arange(2.6, 17, 1)
# Out:
# [  2.6   3.6   4.6   5.6   6.6   7.6   8.6   9.6  10.6  11.6  12.6  13.6
#   14.6  15.6  16.6]
