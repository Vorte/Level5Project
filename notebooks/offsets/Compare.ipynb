# %%
import predictthumb, perfect, pooled
reload(predictthumb)
reload(perfect)
reload(pooled)

noregr = []
pool = []
perf = []
pred = []

# for i in range(5, 6):
#     print ("Processing user %d" %i)

# 7, 13

i=8

before, after = predictthumb.run(i)
pred.append(after)

before, after = pooled.run(i)
pool.append(after)

before, after = perfect.run(i)
perf.append(after)
noregr.append(before)
    

# print "###################"    
# print "Processing Complete"

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#fig = plt.figure(figsize=(10, 7))

#plt.errorbar(range(1,8), noregr[0], linestyle="--", marker="o", label="no model")
plt.errorbar(range(1,8), perf[0], marker="o", label = "perfect")
plt.errorbar(range(1,8), pred[0], linestyle="--", marker="o", label="predict thumb")
plt.errorbar(range(1,8), pool[0], marker="o", label = "pooled")

plt.legend(loc='lower right')
plt.xlabel('virtual button size in mm')
plt.ylabel('% of touches within button')

#plt.savefig('/users/level5/1005056p/Desktop/Latex/L5Project/mpaper/img/compare8.png', bbox_inches='tight', dpi=400)
plt.show()
